# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input director

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
raw_data = pd.read_json("farmers-protest-tweets-2021-2-4.json", lines=True)

# %%
raw_tweets = raw_data[raw_data['lang']=='en']
print("Shape: ", raw_tweets.shape)
raw_tweets.head(5)
# Out:
# Shape:  (48429, 21)
#                                                   url  \
# 0   https://twitter.com/ArjunSinghPanam/status/136...
# 1   https://twitter.com/PrdeepNain/status/13645062...
# 3   https://twitter.com/anmoldhaliwal/status/13645...
# 8   https://twitter.com/anmoldhaliwal/status/13645...
# 11  https://twitter.com/anmoldhaliwal/status/13645...
#
#                         date  \
# 0  2021-02-24 09:23:35+00:00
# 1  2021-02-24 09:23:32+00:00
# 3  2021-02-24 09:23:16+00:00
# 8  2021-02-24 09:22:34+00:00
# 11 2021-02-24 09:21:51+00:00
#
#                                               content  \
# 0   The world progresses while the Indian police a...
# 1   #FarmersProtest \n#ModiIgnoringFarmersDeaths \...
# 3   @ReallySwara @rohini_sgh watch full video here...
# 8   @mandeeppunia1 watch full video here https://t...
# 11  @mandeeppunia1 watch full video here https://t...
#
#                                       renderedContent                   id  \
# ...

# %%
from pandas.io.json import json_normalize
users = json_normalize(raw_tweets['user'])
users.drop(['description', 'linkTcourl'], axis=1, inplace=True)
users.rename(columns={'id':'userId', 'url':'profileUrl'}, inplace=True)
users.head(5)
# Out:
# C:\Users\Nicolas\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#           username        displayname               userId  \
# 0  ArjunSinghPanam  Arjun Singh Panam             45091142
# 1       PrdeepNain       Pradeep Nain  1355092620662329349
# 2    anmoldhaliwal              Anmol            137908912
# 3    anmoldhaliwal              Anmol            137908912
# 4    anmoldhaliwal              Anmol            137908912
#
#                                       rawDescription descriptionUrls  \
# 0  Global Citizen, Actor, Director: Sky is the ro...              []
# 1              Live in the sunshine where you belong              []
# 2                                        coming soon              []
# 3                                        coming soon              []
# 4                                        coming soon              []
#
# ...

# %% [markdown]
# First Request

# %%
most_retweeted = raw_tweets.sort_values(by=['retweetCount'], ascending=False)
most_retweeted['content'].head(10)
# Out:
# 7645      There's a #FarmersProtest happening in Germany...
# 89780     disha ravi, a 21-year-old climate activist, ha...
# 88911     Disha Ravi broke down in court room and told j...
# 111556    Farmers are so sweet. Y’all have to see this @...
# 64492     india is targeting young women to silence diss...
# 108072    Bollywood has betrayed Panjab &amp; the farmer...
# 84368     Please, where did you get your PhD from? Anti-...
# 23348     This is Revolution. More than 2.25lac people a...
# 89423     Wish you fly over the Delhi border and look at...
# 97348     They went after our grandparents.\n#GurmukhSin...
# Name: content, dtype: object

# %%
most_emited = []
for i in raw_tweets["user"]:
  most_emited.append(i["username"])

most_emited = sorted(most_emited, key = most_emited.count, reverse = True)
